# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,mean_squared_error,root_mean_squared_error,confusion_matrix
import pickle as pk

# %%
df= pd.read_csv("loan_approval_dataset.csv")

# %%
df.isna().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.keys()
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.keys()
# Out:
# Index(['loan_id', 'no_of_dependents', 'education', 'self_employed',
#        'income_annum', 'loan_amount', 'loan_term', 'cibil_score',
#        'residential_assets_value', 'commercial_assets_value',
#        'luxury_assets_value', 'bank_asset_value', 'loan_status'],
#       dtype='object')

# %%
df['education'].unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
df['education'] = df['education'].apply(lambda x : x.strip())

# %%
df['education'] = df['education'].replace("Graduate","1").replace("Not Graduate","0").astype(int)

# %%
df['education'].unique()
# Out:
# array([1, 0])

# %%
df['self_employed'].unique()
# Out:
# array([' No', ' Yes'], dtype=object)

# %%
df['self_employed'] = df['self_employed'].apply(lambda x : x.strip())

# %%
df['self_employed'] = df['self_employed'].replace("Yes","1").replace("No","0").astype(int)

# %%
df['self_employed'].unique()
# Out:
# array([0, 1])

# %%
df['loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df['loan_status'] = df['loan_status'].apply(lambda x :x.strip())

# %%
df['loan_status'] = df['loan_status'].replace("Approved","1").replace("Rejected","0").astype(int)

# %%
df['loan_status'].unique()
# Out:
# array([1, 0])

# %%
df['Assets'] = df['residential_assets_value'] + df['commercial_assets_value'] + df['luxury_assets_value'] + df['bank_asset_value']

# %%
df.drop(columns=['loan_id','residential_assets_value','commercial_assets_value','luxury_assets_value','bank_asset_value'],inplace=True)

# %%
df
# Out:
#       no_of_dependents  education  self_employed  income_annum  loan_amount  \
# 0                    2          1              0       9600000     29900000
# 1                    0          0              1       4100000     12200000
# 2                    3          1              0       9100000     29700000
# 3                    3          1              0       8200000     30700000
# 4                    5          0              1       9800000     24200000
# ...                ...        ...            ...           ...          ...
# 4264                 5          1              1       1000000      2300000
# 4265                 0          0              1       3300000     11300000
# 4266                 2          0              0       6500000     23900000
# 4267                 1          0              0       4100000     12800000
# 4268                 1          1              0       9200000     29700000
#
#       loan_term  cibil_score  loan_status    Assets
# ...

# %%
x = df.drop(columns="loan_status")
y = df["loan_status"]

# %%
x.keys()
# Out:
# Index(['no_of_dependents', 'education', 'self_employed', 'income_annum',
#        'loan_amount', 'loan_term', 'cibil_score', 'Assets'],
#       dtype='object')

# %%
# plt.figure(figsize=(10,8))
# sns.heatmap(x.corr(),annot=True)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
scaler = StandardScaler()
scaled_x_train = scaler.fit_transform(x_train)
scaled_x_test = scaler.transform(x_test)

# %% [markdown]
# # Logistic Regression

# %%
model1  = LogisticRegression()

# %%
model1.fit(scaled_x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = model1.predict(scaled_x_test)

# %%
accuracyscore = accuracy_score(y_test,y_pred1)
mse = mean_squared_error(y_test,y_pred1)
rms = np.sqrt(mse)

# %%
print("Accuracy_socre",accuracyscore)
print("Mean_squared,error",mse)
print("Mean_squared,error",rms)
# Out:
# Accuracy_socre 0.9180327868852459
# Mean_squared,error 0.08196721311475409
# Mean_squared,error 0.2862991671569341

# %%
# sns.heatmap(confusion_matrix(y_test,y_pred1),annot=True)

# %% [markdown]
# # Decision Tree

# %%
model2  = DecisionTreeClassifier(criterion="entropy")

# %%
model2.fit(scaled_x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred2 = model2.predict(scaled_x_test)

# %%
accuracyscore = accuracy_score(y_test,y_pred2)
mse = mean_squared_error(y_test,y_pred2)
rms = np.sqrt(mse)

# %%
print("Accuracy_socre",accuracyscore)
print("Mean_squared,error",mse)
print("Mean_squared,error",rms)
# Out:
# Accuracy_socre 0.9836065573770492
# Mean_squared,error 0.01639344262295082
# Mean_squared,error 0.12803687993289598

# %%
# sns.heatmap(confusion_matrix(y_test,y_pred2),annot=True)

# %% [markdown]
# # Random Forest

# %%
model3 = RandomForestClassifier(n_estimators=100)

# %%
model3.fit(scaled_x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = model3.predict(scaled_x_test)

# %%
accuracyscore = accuracy_score(y_test,y_pred3)
mse = mean_squared_error(y_test,y_pred3)
rms = np.sqrt(mse)

# %%
print("Accuracy_socre",accuracyscore)
print("Mean_squared,error",mse)
print("Mean_squared,error",rms)
# Out:
# Accuracy_socre 0.9800936768149883
# Mean_squared,error 0.01990632318501171
# Mean_squared,error 0.14108976995165776

# %%
# sns.heatmap(confusion_matrix(y_test,y_pred2),annot=True)

# %%
pred_data = pd.DataFrame([['2','1','0','9600000','29900000','12','778','50700000']],columns=['no_of_dependents', 'education', 'self_employed', 'income_annum','loan_amount', 'loan_term', 'cibil_score', 'Assets'])

# %%
pred_data
# Out:
#   no_of_dependents education self_employed income_annum loan_amount loan_term  \
# 0                2         1             0      9600000    29900000        12
#
#   cibil_score    Assets
# 0         778  50700000

# %%
scaler.transform(pred_data)
# Out:
# array([[-0.29434668,  0.98690853, -1.00322629,  1.62161264,  1.62627708,
#          0.19538724,  1.02917992,  0.93622493]])

# %%
#using logistic regression makea prediction
model1.predict(pred_data)
# Out:
# c:\Users\INDIA\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([1])

# %%
pk.dump(model1,open('logisticreg.pkl','wb'))

# %%
pk.dump(model2,open('decisiontree.pkl','wb'))

# %%
pk.dump(model3,open('randomforest.pkl','wb'))

# %%
pk.dump(scaler,open("scaler.pkl",'wb'))
